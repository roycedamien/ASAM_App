# %% [markdown]
# <a href="https://colab.research.google.com/github/roycedamien/ASAM_App/blob/master/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Unsloth Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 5335, done.
# remote: Counting objects: 100% (5335/5335), done.
# remote: Compressing objects: 100% (5119/5119), done.
# remote: Total 5335 (delta 240), reused 2268 (delta 172), pack-reused 0 (from 0)
# Receiving objects: 100% (5335/5335), 57.78 MiB | 17.16 MiB/s, done.
# Resolving deltas: 100% (240/240), done.
# Updating files: 100% (5011/5011), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  installing isolated Node (system Node/npm left untouched)...
#   node           v24.18.0 | npm 11.16.0 (isolated)
#                  installing bun...
#                  bun installed (1.4.2)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Unsloth backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/16  base packages
#   deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [=======-------------]  6/16  dependency overrides
#                  torch 2.11.0+cu128 detected -- installing torchao==0.17.0
#   deps           [====================] 16/16  torch final (cuda)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#   transformers   5.10.2 pre-installed
#   gpu            NVIDIA GPU detected
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b10798-mix-659e406 (tag b10798)
#   whisper.cpp    prebuilt installed
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start

# On Colab, start() auto-opens a Cloudflare link and prints admin login credentials.
# Use the Cloudflare link above the ready card to open Unsloth (in-cell iframes often stay blank).
start()

# To skip the Cloudflare tunnel and try the in-notebook proxy iframe only:
# start(cloudflare=False)
# Out:
# 2026-09-06 19:49:01 [info     ] 🦥 Starting Unsloth Studio...
# {"timestamp": "2026-09-06T19:49:07.051657Z", "level": "info", "event": "   Loading backend..."}
# {"timestamp": "2026-09-06T19:49:07.077172Z", "level": "info", "event": "   Starting server..."}
# {"timestamp": "2026-09-06T19:49:07.079037Z", "level": "info", "event": "run_server startup begin api_only=False host=0.0.0.0 port=8888"}
# {"timestamp": "2026-09-06T19:49:07.117308Z", "level": "info", "event": "Imported FastAPI app in 1.8ms"}
# {"timestamp": "2026-09-06T19:49:07.121483Z", "level": "info", "event": "Ensured Unsloth directories in 43.8ms"}
# {"timestamp": "2026-09-06T19:49:07.344263Z", "level": "info", "event": "run_server pre-uvicorn setup completed in 266.5ms"}
# INFO:     Started server process [2592]
# INFO:     Waiting for application startup.
# {"timestamp": "2026-09-06T19:49:07.437238Z", "level": "info", "event": "Removing unsloth compiled cache: /root/.unsloth/studio/compiled_cache"}
# {"timestamp": "2026-09-06T19:49:07.691182Z", "level": "info", "event": "lifespan pre-auth setup completed in 255.5ms"}
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Unsloth UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-09-06T19:49:07.830909Z", "level": "info", "event": "lifespan startup completed in 395.3ms"}
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://172.28.0.12:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# {"timestamp": "2026-09-06T19:49:07.843911Z", "level": "info", "event": "Uvicorn startup hook completed in 766.2ms"}
# {"timestamp": "2026-09-06T19:49:07.849721Z", "level": "info", "event": "run_server uvicorn ready after 772.0ms"}
# {"timestamp": "2026-09-06T19:49:07.959710Z", "level": "info", "event": "   Server started on port 8888!"}
# {"timestamp": "2026-09-06T19:49:10.370468Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 2269.01}
# Hardware detected: CUDA -- Tesla T4
# {"timestamp": "2026-09-06T19:49:10.503624Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-09-06T19:49:21.339475Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 3.52}
# {"timestamp": "2026-09-06T19:49:25.047617Z", "level": "info", "event": "torch warm finished in 17218.3ms"}
# {"timestamp": "2026-09-06T19:49:33.349421Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-t4-s-kkb-ass1b0-wdeoszky0gmi-b.asia-southeast1-0.prod.colab.dev"}
# {"timestamp": "2026-09-06T19:49:33.350468Z", "level": "info", "event": "\ud83d\udd17 Shareable Cloudflare link: https://precisely-mesa-calcium-jul.trycloudflare.com"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Shareable Unsloth Link is Ready!
#         </h2>
#         <a href="https://precisely-mesa-calcium-jul.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px; cursor: pointer;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             This Cloudflare HTTPS link works from any device, so you can share it with anyone.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             🔗 <a href="https://precisely-mesa-calcium-jul.trycloudflare.com" onclick="var w=window.open(this.href,'_blank');if(!w){return true;}return false;"
#                   style="color: #000000; text-decoration: underline; cursor: pointer;">https://precisely-mesa-calcium-jul.trycloudflare.com</a>
#         </p>
#         <p style="color: #000000; margin: 16px 0 0 0; font-size: 20px; font-weight: 800;">
#             Password
#         </p>
#         <p style="margin: 6px 0 0 0;"><code style="display: inline-block; font-size: 24px;
#             font-weight: 800; text-decoration: underline; background: #f3f3f3;
#             padding: 4px 10px; border-radius: 6px;">ZigzaggedCaddyFacilitySnowflake</code></p>
#         <p style="color: #666666; margin: 6px 0 0 0; font-size: 12px;">
#             Log in as <code>unsloth</code> with this password. Shown only in your
#             notebook session, and never included in the shared link.
#         </p>
#     </div>
# =={"timestamp": "2026-09-06T20:02:06.611332Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 6.89}
# {"timestamp": "2026-09-06T20:02:06.993156Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/theme-boot.js", "status_code": 200, "process_time_ms": 29.9}
# {"timestamp": "2026-09-06T20:02:06.999540Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/crypto-boot.js", "status_code": 200, "process_time_ms": 18.64}
# {"timestamp": "2026-09-06T20:02:07.001320Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/reload-snapshot.js", "status_code": 200, "process_time_ms": 14.12}
# {"timestamp": "2026-09-06T20:02:23.582185Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 3.06}
# {"timestamp": "2026-09-06T20:02:24.307522Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.6}
# {"timestamp": "2026-09-06T20:02:34.519175Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 90.97}
# {"timestamp": "2026-09-06T20:02:34.871274Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 4.08}
# {"timestamp": "2026-09-06T20:02:35.147853Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-09-06T20:02:35.156569Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ucWEO3O", "status_code": 404, "process_time_ms": 19.8}
# {"timestamp": "2026-09-06T20:02:35.207371Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 53.16}
# {"timestamp": "2026-09-06T20:02:35.211230Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/rag/knowledge-bases", "status_code": 200, "process_time_ms": 46.46}
# {"timestamp": "2026-09-06T20:02:36.360115Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 1186.19}
# {"timestamp": "2026-09-06T20:02:36.368036Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 1175.88}
# {"timestamp": "2026-09-06T20:02:36.369284Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/hidden-models", "status_code": 200, "process_time_ms": 1182.99}
# {"timestamp": "2026-09-06T20:02:36.406204Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ucWEO3O", "status_code": 404, "process_time_ms": 13.1}
# {"timestamp": "2026-09-06T20:02:36.681307Z", "level": "info", "event": "Fetched 40 top GGUF models"}
# {"timestamp": "2026-09-06T20:02:36.682579Z", "level": "info", "event": "Fetched 26 top hub models"}
# {"timestamp": "2026-09-06T20:02:37.705065Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 11.85}
# {"timestamp": "2026-09-06T20:02:37.851269Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/hugging-face-token", "status_code": 200, "process_time_ms": 9.05}
# {"timestamp": "2026-09-06T20:02:40.566354Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 14.54}
# {"timestamp": "2026-09-06T20:02:40.580474Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_g9lsnSq", "status_code": 404, "process_time_ms": 29.62}
# {"timestamp": "2026-09-06T20:02:40.608694Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 14.35}
# {"timestamp": "2026-09-06T20:02:40.616354Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_ucWEO3O", "status_code": 404, "process_time_ms": 18.29}
# {"timestamp": "2026-09-06T20:02:40.658416Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/settings/chat-preferences/migrate", "status_code": 200, "process_time_ms": 23.77}
# {"timestamp": "2026-09-06T20:02:41.011579Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 465.79}
# {"timestamp": "2026-09-06T20:02:41.014223Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-09-06T20:02:41.015528Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-09-06T20:02:42.012708Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/recommended-folders", "status_code": 200, "process_time_ms": 13.33}
# {"timestamp": "2026-09-06T20:02:42.020108Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/scan-folders", "status_code": 200, "process_time_ms": 25.58}
# {"timestamp": "2026-09-06T20:02:42.032943Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/vram-budget", "status_code": 200, "process_time_ms": 40.29}
# {"timestamp": "2026-09-06T20:02:42.110613Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-06T20:02:45.225214Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/openapi.json", "status_code": 200, "process_time_ms": 3188.93}
# {"timestamp": "2026-09-06T20:02:45.232096Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 3228.21}
# {"timestamp": "2026-09-06T20:02:45.234600Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 3239.41}
# {"timestamp": "2026-09-06T20:02:45.277191Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 30.32}
# {"timestamp": "2026-09-06T20:02:45.281051Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_g9lsnSq", "status_code": 404, "process_time_ms": 35.03}
# {"timestamp": "2026-09-06T20:02:45.539625Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-09-06T20:02:45.541094Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/rag/knowledge-bases", "status_code": 200, "process_time_ms": 292.75}
# {"timestamp": "2026-09-06T20:02:45.546739Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-09-06T20:02:45.580738Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 329.28}
# {"timestamp": "2026-09-06T20:02:45.768437Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 9.28}
# {"timestamp": "2026-09-06T20:02:46.733851Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 21.82}
# {"timestamp": "2026-09-06T20:02:46.734717Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-06T20:02:46.738350Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 17.92}
# {"timestamp": "2026-09-06T20:02:46.740582Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 24.63}
# {"timestamp": "2026-09-06T20:02:47.156748Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 253.53}
# {"timestamp": "2026-09-06T20:02:53.493847Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.84}
# {"timestamp": "2026-09-06T20:02:57.546959Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 253.36}
# {"timestamp": "2026-09-06T20:03:03.970623Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.79}
# {"timestamp": "2026-09-06T20:03:07.573198Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 239.0}
# {"timestamp": "2026-09-06T20:03:07.976105Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 397.78}
# {"timestamp": "2026-09-06T20:03:14.766528Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.93}
# {"timestamp": "2026-09-06T20:03:17.693976Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 240.28}
# {"timestamp": "2026-09-06T20:03:18.761121Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 396.35}
# {"timestamp": "2026-09-06T20:03:18.942019Z", "level": "info", "event": "Cached model scan: inspected=0 skipped_gguf=0 skipped_no_weights=0 returned=0"}
# {"timestamp": "2026-09-06T20:03:18.950330Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-models", "status_code": 200, "process_time_ms": 23.34}
# {"timestamp": "2026-09-06T20:03:18.951696Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/cached-gguf", "status_code": 200, "process_time_ms": 19.02}
# {"timestamp": "2026-09-06T20:03:18.955378Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/hub/local", "status_code": 200, "process_time_ms": 26.33}
# {"timestamp": "2026-09-06T20:03:25.588348Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.95}
# {"timestamp": "2026-09-06T20:03:29.132568Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 230.95}
# {"timestamp": "2026-09-06T20:03:31.812966Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 361.88}
# {"timestamp": "2026-09-06T20:03:36.124397Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.62}
# {"timestamp": "2026-09-06T20:03:39.625374Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 245.91}
# {"timestamp": "2026-09-06T20:03:46.878454Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.91}
# {"timestamp": "2026-09-06T20:03:49.711150Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads/__LOCALID_g9lsnSq", "status_code": 404, "process_time_ms": 3.74}
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# WARNING:torchao:Failed to load /usr/local/lib/python3.13/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.13/dist-packages/torchao/_C_cutlass_90a.abi3.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.13/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.13/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# {"timestamp": "2026-09-06T20:03:54.821955Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/prompts/entries", "status_code": 200, "process_time_ms": 50.17}
# {"timestamp": "2026-09-06T20:03:56.407784Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/download-transport", "status_code": 200, "process_time_ms": 6156.56}
# {"timestamp": "2026-09-06T20:03:57.544698Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.15}
# {"timestamp": "2026-09-06T20:03:57.731346Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/download-transport-capabilities", "status_code": 200, "process_time_ms": 961.27}
# {"timestamp": "2026-09-06T20:03:59.128185Z", "level": "info", "event": "Download transport for unsloth/Qwen3.8-27B-GGUF: xet (Xet (requested))"}
# {"timestamp": "2026-09-06T20:03:59.177875Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/hub/download", "status_code": 202, "process_time_ms": 275.48}
# {"timestamp": "2026-09-06T20:03:59.432922Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/settings/xet-notice/reserve", "status_code": 200, "process_time_ms": 9.76}
# {"timestamp": "2026-09-06T20:04:02.007463Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/Qwen3.8-27B-GGUF", "variant": "UD-Q4_K_XL", "percent": 0}
# {"timestamp": "2026-09-06T20:04:08.131143Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.03}
# {"timestamp": "2026-09-06T20:04:12.234963Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/Qwen3.8-27B-GGUF", "variant": "UD-Q4_K_XL", "percent": 10}
# {"timestamp": "2026-09-06T20:04:17.922175Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/Qwen3.8-27B-GGUF", "variant": "UD-Q4_K_XL", "percent": 20}
# {"timestamp": "2026-09-06T20:04:18.405910Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/prompts/entries", "status_code": 200, "process_time_ms": 15.14}
# {"timestamp": "2026-09-06T20:04:19.824689Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 2.89}
# {"timestamp": "2026-09-06T20:04:28.391290Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/Qwen3.8-27B-GGUF", "variant": "UD-Q4_K_XL", "percent": 30}
# {"timestamp": "2026-09-06T20:04:29.821456Z", "level": "error", "event": "request_failed", "path": "/api/chat/settings", "method": "PUT", "status_code": 500, "error": "database is locked", "process_time_ms": 5093.2, "exception": "Traceback (most recent call last):\n  File \"/content/unsloth/studio/backend/loggers/handlers.py\", line 325, in __call__\n    await self.app(scope, receive, send_wrapper)\n  File \"/usr/local/lib/python3.13/dist-packages/starlette/middleware/exceptions.py\", line 63, in __call__\n    await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)\n  File \"/usr/local/lib/python3.13/dist-packages/starlette/_exception_handler.py\", line 53, in wrapped_app\n    raise exc\n  File \"/usr/local/lib/python3.13/dist-packages/starlette/_exception_handler.py\", line 42, in wrapped_app\n    await app(scope, receive, sender)\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/middleware/asyncexitstack.py\", line 18, in __call__\n    await self.app(scope, receive, send)\n  File \"/usr/local/lib/python3.13/dist-packages/starlette/routing.py\", line 670, in __call__\n    await self.middleware_stack(scope, receive, send)\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/routing.py\", line 2734, in app\n    await route.handle(scope, receive, send)\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/routing.py\", line 1780, in handle\n    await self.original_router.handle(scope, receive, send)\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/routing.py\", line 2789, in handle\n    await included_router._handle_selected(scope, receive, send)\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/routing.py\", line 1800, in _handle_selected\n    await original_route.handle(scope, receive, send)\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/routing.py\", line 1279, in handle\n    await app(scope, receive, send)\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/routing.py\", line 158, in app\n    await wrap_app_handling_exceptions(app, request)(scope, receive, send)\n  File \"/usr/local/lib/python3.13/dist-packages/starlette/_exception_handler.py\", line 53, in wrapped_app\n    raise exc\n  File \"/usr/local/lib/python3.13/dist-packages/starlette/_exception_handler.py\", line 42, in wrapped_app\n    await app(scope, receive, sender)\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/routing.py\", line 144, in app\n    response = await f(request)\n               ^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/routing.py\", line 706, in app\n    raw_response = await run_endpoint_function(\n                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n    ...<3 lines>...\n    )\n    ^\n  File \"/usr/local/lib/python3.13/dist-packages/fastapi/routing.py\", line 354, in run_endpoint_function\n    return await run_in_threadpool(dependant.call, **values)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.13/dist-packages/starlette/concurrency.py\", line 34, in run_in_threadpool\n    return await anyio.to_thread.run_sync(func)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File \"/usr/local/lib/python3.13/dist-packages/anyio/to_thread.py\", line 63, in run_sync\n    return await get_async_backend().run_sync_in_worker_thread(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n        func, args, abandon_on_cancel=abandon_on_cancel, limiter=limiter\n        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n    )\n    ^\n  File \"/usr/local/lib/python3.13/dist-packages/anyio/_backends/_asyncio.py\", line 2518, in run_sync_in_worker_thread\n    return await future\n           ^^^^^^^^^^^^\n  File \"/usr/lib/python3.13/asyncio/futures.py\", line 286, in __await__\n    yield self  # This tells Task to wait for completion.\n    ^^^^^^^^^^\n  File \"/usr/lib/python3.13/asyncio/tasks.py\", line 375, in __wakeup\n    future.result()\n    ~~~~~~~~~~~~~^^\n  File \"/usr/lib/python3.1 ...
# | Traceback (most recent call last):
# |   File "/content/unsloth/studio/backend/loggers/handlers.py", line 325, in __call__
# |     await self.app(scope, receive, send_wrapper)
# |   File "/usr/local/lib/python3.13/dist-packages/starlette/middleware/exceptions.py", line 63, in __call__
# |     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
# |   File "/usr/local/lib/python3.13/dist-packages/starlette/_exception_handler.py", line 53, in wrapped_app
# |     raise exc
# |   File "/usr/local/lib/python3.13/dist-packages/starlette/_exception_handler.py", line 42, in wrapped_app
# |     await app(scope, receive, sender)
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/middleware/asyncexitstack.py", line 18, in __call__
# |     await self.app(scope, receive, send)
# |   File "/usr/local/lib/python3.13/dist-packages/starlette/routing.py", line 670, in __call__
# |     await self.middleware_stack(scope, receive, send)
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/routing.py", line 2734, in app
# |     await route.handle(scope, receive, send)
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/routing.py", line 1780, in handle
# |     await self.original_router.handle(scope, receive, send)
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/routing.py", line 2789, in handle
# |     await included_router._handle_selected(scope, receive, send)
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/routing.py", line 1800, in _handle_selected
# |     await original_route.handle(scope, receive, send)
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/routing.py", line 1279, in handle
# |     await app(scope, receive, send)
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/routing.py", line 158, in app
# |     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
# |   File "/usr/local/lib/python3.13/dist-packages/starlette/_exception_handler.py", line 53, in wrapped_app
# |     raise exc
# |   File "/usr/local/lib/python3.13/dist-packages/starlette/_exception_handler.py", line 42, in wrapped_app
# |     await app(scope, receive, sender)
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/routing.py", line 144, in app
# |     response = await f(request)
# |                ^^^^^^^^^^^^^^^^
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/routing.py", line 706, in app
# |     raw_response = await run_endpoint_function(
# |                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |     ...<3 lines>...
# |     )
# |     ^
# |   File "/usr/local/lib/python3.13/dist-packages/fastapi/routing.py", line 354, in run_endpoint_function
# |     return await run_in_threadpool(dependant.call, **values)
# |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/usr/local/lib/python3.13/dist-packages/starlette/concurrency.py", line 34, in run_in_threadpool
# |     return await anyio.to_thread.run_sync(func)
# |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |   File "/usr/local/lib/python3.13/dist-packages/anyio/to_thread.py", line 63, in run_sync
# |     return await get_async_backend().run_sync_in_worker_thread(
# |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |         func, args, abandon_on_cancel=abandon_on_cancel, limiter=limiter
# |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# |     )
# |     ^
# |   File "/usr/local/lib/python3.13/dist-packages/anyio/_backends/_asyncio.py", line 2518, in run_sync_in_worker_thread
# |     return await future
# |            ^^^^^^^^^^^^
# |   File "/usr/lib/python3.13/asyncio/futures.py", line 286, in __await__
# |     yield self  # This tells Task to wait for completion.
# |     ^^^^^^^^^^
# |   File "/usr/lib/python3.13/asyncio/tasks.py", line 375, in __wakeup
# |     future.result()
# |     ~~~~~~~~~~~~~^^
# |   File "/usr/lib/python3.13/asyncio/futures.py", line 199, in result
# |     raise self._exception.with_traceback(self._exception_tb)
# |   File "/usr/local/lib/python3.13/dist-packages/anyio/_backends/_asyncio.py", line 1002, in run
# |     result = context.run(func, *args)
# |   File "/content/unsloth/studio/backend/routes/chat_history.py", line 1614, in put_settings
# |     settings = upsert_chat_settings_merge(parsed.model_dump(exclude_unset = True))
# |   File "/content/unsloth/studio/backend/storage/studio_db.py", line 4662, in upsert_chat_settings_merge
# |     conn.execute("BEGIN IMMEDIATE")
# |     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# | sqlite3.OperationalError: database is locked
# {"timestamp": "2026-09-06T20:04:30.326628Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 11.37}
# {"timestamp": "2026-09-06T20:04:33.126765Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/mcp/servers/", "status_code": 200, "process_time_ms": 8783.37}
# ={"timestamp": "2026-09-06T20:04:35.798201Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/mcp/servers/", "status_code": 200, "process_time_ms": 5.32}
# {"timestamp": "2026-09-06T20:04:37.369501Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/mcp/servers/", "status_code": 200, "process_time_ms": 5.95}
# {"timestamp": "2026-09-06T20:04:40.793230Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 3.0}
# {"timestamp": "2026-09-06T20:04:41.545069Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/mcp/servers/", "status_code": 200, "process_time_ms": 4.76}
# {"timestamp": "2026-09-06T20:04:48.207659Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 13.11}
# {"timestamp": "2026-09-06T20:04:48.464581Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 269.18}
# {"timestamp": "2026-09-06T20:04:48.504143Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/settings/openai-auto-switch", "status_code": 200, "process_time_ms": 305.28}
# {"timestamp": "2026-09-06T20:04:48.810078Z", "level": "info", "event": "hub_download_progress", "repo_id": "unsloth/Qwen3.8-27B-GGUF", "variant": "UD-Q4_K_XL", "percent": 40}
# {"timestamp": "2026-09-06T20:04:49.272642Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/mcp/servers/", "status_code": 200, "process_time_ms": 51.23}
# {"timestamp": "2026-09-06T20:04:51.813344Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/monitor", "status_code": 200, "process_time_ms": 14.96}
# {"timestamp": "2026-09-06T20:04:54.338484Z", "level": "info", "event": "request_completed", "method": "PUT", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 35.39}

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
